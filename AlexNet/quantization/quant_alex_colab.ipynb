# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# %rm -r -f pytorch-tutorial
# !git clone https://github.com/jungwy1/pytorch-tutorial.git
# %cd pytorch-tutorial/AlexNet/quantization
# Out:
# /content
# Cloning into 'pytorch-tutorial'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 143 (delta 65), reused 113 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 265.50 KiB | 1.34 MiB/s, done.
# Resolving deltas: 100% (65/65), done.
# /content/pytorch-tutorial/AlexNet/quantization

# %%
# !ls
# Out:
# dataset.py  model.py	      quant_basics.py
# engine.py   quant_alexnet.py  quant_linear_layer.py

# %%
# !python quant_alexnet.py
# Out:
# features on cuda, int8 classifier on cpu
# float    top-1: 76.20%   (3925 imgs)
# int8 FC  top-1: 76.10%
