# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# %rm -r -f pytorch-tutorial
# !git clone https://github.com/jungwy1/pytorch-tutorial.git
# %cd pytorch-tutorial/AlexNet/pruning
# Out:
# /content
# Cloning into 'pytorch-tutorial'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 98 (delta 42), reused 81 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 195.25 KiB | 1.60 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/pytorch-tutorial/AlexNet/pruning

# %%
# !ls
# Out:
# dataset.py  prune_finetune_colab.ipynb	prune_sweep.py
# engine.py   prune_finetune.py		pruning_curve_no_finetune.png
# model.py    prune_sweep_colab.ipynb	pruning_curve_with_finetune.png

# %%
# !pip install adjustText

# %%
# !python prune_finetune.py
# Out:
# Using cuda device
# start pruning in COLAB
# 100% 342M/342M [00:10<00:00, 33.4MB/s]
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.794963
#
# loss: 0.869108 [  128/ 9469]
# loss: 0.420116 [ 2688/ 9469]
# loss: 0.553800 [ 5248/ 9469]
# loss: 0.446192 [ 7808/ 9469]
# loss: 0.397576 [  128/ 9469]
# loss: 0.376528 [ 2688/ 9469]
# loss: 0.529051 [ 5248/ 9469]
# loss: 0.366171 [ 7808/ 9469]
# loss: 0.439098 [  128/ 9469]
# loss: 0.483792 [ 2688/ 9469]
# loss: 0.394023 [ 5248/ 9469]
# loss: 0.400317 [ 7808/ 9469]
# loss: 0.484279 [  128/ 9469]
# loss: 0.323775 [ 2688/ 9469]
# loss: 0.303267 [ 5248/ 9469]
# loss: 0.269754 [ 7808/ 9469]
# loss: 0.351213 [  128/ 9469]
# loss: 0.204544 [ 2688/ 9469]
# loss: 0.516738 [ 5248/ 9469]
# loss: 0.377019 [ 7808/ 9469]
# loss: 0.324808 [  128/ 9469]
# loss: 0.349931 [ 2688/ 9469]
# loss: 0.437848 [ 5248/ 9469]
# loss: 0.413406 [ 7808/ 9469]
# loss: 0.418018 [  128/ 9469]
# loss: 0.340879 [ 2688/ 9469]
# loss: 0.240889 [ 5248/ 9469]
# ...
