# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# %rm -r -f pytorch-tutorial
# !git clone https://github.com/jungwy1/pytorch-tutorial.git
# %cd pytorch-tutorial/AlexNet/pruning
# Out:
# /content
# Cloning into 'pytorch-tutorial'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 109 (delta 49), reused 88 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 253.19 KiB | 3.13 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /content/pytorch-tutorial/AlexNet/pruning

# %%
# !ls
# Out:
# dataset.py		    prune_permanent.py
# engine.py		    prune_sweep_colab.ipynb
# model.py		    prune_sweep.py
# prune_finetune_colab.ipynb  pruning_curve_no_finetune.png
# prune_finetune.py	    pruning_curve_with_finetune.png

# %%
# !python prune_permanent.py
# Out:
# Using cuda device
# start pruning in COLAB
# 100% 342M/342M [00:10<00:00, 34.0MB/s]
# loss: 2.090025 [  128/ 9469]
# loss: 1.863396 [ 2688/ 9469]
# loss: 1.664350 [ 5248/ 9469]
# loss: 1.401088 [ 7808/ 9469]
# loss: 1.310960 [  128/ 9469]
# loss: 1.227640 [ 2688/ 9469]
# loss: 0.987367 [ 5248/ 9469]
# loss: 0.930590 [ 7808/ 9469]
# loss: 0.804782 [  128/ 9469]
# loss: 0.907413 [ 2688/ 9469]
# loss: 0.883832 [ 5248/ 9469]
# loss: 0.677805 [ 7808/ 9469]
# loss: 0.749020 [  128/ 9469]
# loss: 0.644363 [ 2688/ 9469]
# loss: 0.690644 [ 5248/ 9469]
# loss: 0.664917 [ 7808/ 9469]
# loss: 0.710769 [  128/ 9469]
# loss: 0.626750 [ 2688/ 9469]
# loss: 0.682983 [ 5248/ 9469]
# loss: 0.479252 [ 7808/ 9469]
# loss: 0.674893 [  128/ 9469]
# loss: 0.647547 [ 2688/ 9469]
# loss: 0.624371 [ 5248/ 9469]
# loss: 0.657094 [ 7808/ 9469]
# loss: 0.447513 [  128/ 9469]
# loss: 0.729827 [ 2688/ 9469]
# loss: 0.627010 [ 5248/ 9469]
# loss: 0.642397 [ 7808/ 9469]
# loss: 0.500713 [  128/ 9469]
# loss: 0.715048 [ 2688/ 9469]
# loss: 0.503721 [ 5248/ 9469]
# loss: 0.593260 [ 7808/ 9469]
# sparsity: 90.0%
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.740689
#
# reload check:
# sparsity: 90.0%
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.740689
