# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# 모든 TorchVision 데이터셋들은 feature와 label을 위한 transform, target_transform 매개변수를 가짐
# torchvision.transforms는 주로 사용하는 몇가지 transform들을 제공

# FashionMNIST의 feature는 PIL Image, label은 integer
# 학습을 위해서는 normalize된 tensor 형태의 feature와, one-hot encoding된 label이 필요

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

ds = datasets.FashionMNIST(
    root = "data",
    train = True,
    download = True,
    # ToTensor는 PIL Image나 NumPy ndarray를 FloatTensor로 변환 후 픽셀의 크기를 [0., 1.]으로 normalization
    transform = ToTensor(),
    # Lambda는 내가 만든 임의의 함수를 transform으로 쓸 수 있게 감싸주는 도구
    # lambda는 파이썬에서 간단한 함수를 한 줄로 즉석에서 만드는 문법
    # torch.zeros(10, dtype = float)로 10칸짜리 tensor 만들고
    # .scatter_(0, torch.tensor(y), value = 1)로 one-hot 뿌림
    #       첫번째 인자: 어느 차원에 뿌릴 건지
    #                   1차원 벡터니까, 차원 idx = 0
    #       두번째 인자: 차원 내 인덱스; tensor로 줘야함
    #       value: 어떤 값을 뿌릴 건지
    target_transform = Lambda(lambda y: torch.zeros(10, dtype = torch.float).scatter_(0, torch.tensor(y), value=1))
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 11.9MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 203kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.78MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 23.8MB/s]
